# %% [markdown]
# <a href="https://colab.research.google.com/github/SeonHyungJo/tensorflow-2.0-study/blob/master/TensorFlow_Tutorial/%EA%B3%BC%EB%8C%80%EC%A0%81%ED%95%A9%EA%B3%BC_%EA%B3%BC%EC%86%8C%EC%A0%81%ED%95%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 앞서 영화 리뷰 분류와 주택 가격 예측의 두 예제에서 일정 에포크 동안 훈련하면 검증 세트에서 모델 성능이 최고점에 도달한 다음 감소하기 시작한 것을 보았습니다.
#
# 다른 말로 하면, 모델이 훈련 세트에 과대적합(overfitting)된 것입니다. 과대적합을 다루는 방법은 꼭 배워야 합니다. 훈련 세트에서 높은 성능을 얻을 수 있지만 진짜 원하는 것은 테스트 세트(또는 이전에 본 적 없는 데이터)에 잘 일반화되는 모델입니다.
#
# 과대적합의 반대는 과소적합(underfitting)입니다. 과소적합은 테스트 세트의 성능이 향상될 여지가 아직 있을 때 일어납니다. 발생하는 원인은 여러가지입니다. 모델이 너무 단순하거나, 규제가 너무 많거나, 그냥 단순히 충분히 오래 훈련하지 않는 경우입니다. 즉 네트워크가 훈련 세트에서 적절한 패턴을 학습하지 못했다는 뜻입니다.
#
# 모델을 너무 오래 훈련하면 과대적합되기 시작하고 테스트 세트에서 일반화되지 못하는 패턴을 훈련 세트에서 학습합니다. 과대적합과 과소적합 사이에서 균형을 잡아야 합니다. 이를 위해 적절한 에포크 횟수동안 모델을 훈련하는 방법을 배워보겠습니다.
#
# 과대적합을 막는 가장 좋은 방법은 더 많은 훈련 데이터를 사용하는 것입니다. 많은 데이터에서 훈련한 모델은 자연적으로 일반화 성능이 더 좋습니다. 데이터를 더 준비할 수 없을 때 그다음으로 가장 좋은 방법은 규제(regularization)와 같은 기법을 사용하는 것입니다. 모델이 저장할 수 있는 정보의 양과 종류에 제약을 부과하는 방법입니다. 네트워크가 소수의 패턴만 기억할 수 있다면 최적화 과정 동안 일반화 가능성이 높은 가장 중요한 패턴에 촛점을 맞출 것입니다.
#
# 이 노트북에서 널리 사용되는 두 가지 규제 기법인 가중치 규제와 드롭아웃(dropout)을 알아 보겠습니다. 이런 기법을 사용하여 IMDB 영화 리뷰 분류 모델의 성능을 향상시켜 보죠.

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# # IMDB 데이터셋 다운로드
# 이전 노트북에서처럼 임베딩을 사용하지 않고 여기에서는 문장을 멀티-핫 인코딩(multi-hot encoding)으로 변환하겠습니다. 이 모델은 훈련 세트에 빠르게 과대적합될 것입니다. 과대적합을 발생시키고 어떻게 해결하는지 보이기 위해 선택했습니다.
#
# 멀티-핫 인코딩은 정수 시퀀스를 0과 1로 이루어진 벡터로 변환합니다. 정확하게 말하면 시퀀스 [3, 5]를 인덱스 3과 5만 1이고 나머지는 모두 0인 10,000 차원 벡터로 변환한다는 의미입니다.

# %%
NUM_WORDS = 1000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # 0으로 채워진 (len(sequences), dimension) 크기의 행렬을 만듭니다
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # results[i]의 특정 인덱스만 1로 설정합니다
    return results

train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)
# Out:
# [list([1, 14, 22, 16, 43, 530, 973, 2, 2, 65, 458, 2, 66, 2, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 2, 2, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2, 19, 14, 22, 4, 2, 2, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 2, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2, 2, 16, 480, 66, 2, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 2, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 2, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 2, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 2, 88, 12, 16, 283, 5, 16, 2, 113, 103, 32, 15, 16, 2, 19, 178, 32])
#  list([1, 194, 2, 194, 2, 78, 228, 5, 6, 2, 2, 2, 134, 26, 4, 715, 8, 118, 2, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 2, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2, 2, 5, 647, 4, 116, 9, 35, 2, 4, 229, 9, 340, 2, 4, 118, 9, 4, 130, 2, 19, 4, 2, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 2, 2, 398, 4, 2, 26, 2, 5, 163, 11, 2, 2, 4, 2, 9, 194, 775, 7, 2, 2, 349, 2, 148, 605, 2, 2, 15, 123, 125, 68, 2, 2, 15, 349, 165, 2, 98, 5, 4, 228, 9, 43, 2, 2, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 2, 228, 2, 5, 2, 656, 245, 2, 5, 4, 2, 131, 152, 491, 18, 2, 32, 2, 2, 14, 9, 6, 371, 78, 22, 625, 64, 2, 9, 8, 168, 145, 23, 4, 2, 15, 16, 4, 2, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95])
#  list([1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 2, 54, 61, 369, 13, 71, 149, 14, 22, 112, 4, 2, 311, 12, 16, 2, 33, 75, 43, 2, 296, 4, 86, 320, 35, 534, 19, 263, 2, 2, 4, 2, 33, 89, 78, 12, 66, 16, 4, 360, 7, 4, 58, 316, 334, 11, 4, 2, 43, 645, 662, 8, 257, 85, 2, 42, 2, 2, 83, 68, 2, 15, 36, 165, 2, 278, 36, 69, 2, 780, 8, 106, 14, 2, 2, 18, 6, 22, 12, 215, 28, 610, 40, 6, 87, 326, 23, 2, 21, 23, 22, 12, 272, 40, 57, 31, 11, 4, 22, 47, 6, 2, 51, 9, 170, 23, 595, 116, 595, 2, 13, 191, 79, 638, 89, 2, 14, 9, 8, 106, 607, 624, 35, 534, 6, 227, 7, 129, 113])
#  ...
#  list([1, 11, 6, 230, 245, 2, 9, 6, 2, 446, 2, 45, 2, 84, 2, 2, 21, 4, 912, 84, 2, 325, 725, 134, 2, 2, 84, 5, 36, 28, 57, 2, 21, 8, 140, 8, 703, 5, 2, 84, 56, 18, 2, 14, 9, 31, 7, 4, 2, 2, 2, 2, 2, 18, 6, 20, 207, 110, 563, 12, 8, 2, 2, 8, 97, 6, 20, 53, 2, 74, 4, 460, 364, 2, 29, 270, 11, 960, 108, 45, 40, 29, 2, 395, 11, 6, 2, 500, 7, 2, 89, 364, 70, 29, 140, 4, 64, 2, 11, 4, 2, 26, 178, 4, 529, 443, 2, 5, 27, 710, 117, 2, 2, 165, 47, 84, 37, 131, 818, 14, 595, 10, 10, 61, 2, 2, 10, 10, 288, 2, 2, 34, 2, 2, 4, 65, 496, 4, 231, 7, 790, 5, 6, 320, 234, 2, 234, 2, 2, 7, 496, 4, 139, 929, 2, 2, 2, 5, 2, 18, 4, 2, 2, 250, 11, 2, 2, 4, 2, 2, 747, 2, 372, 2, 2, 541, 2, 7, 4, 59, 2, 4, 2, 2])
#  list([1, 2, 2, 69, 72, 2, 13, 610, 930, 8, 12, 582, 23, 5, 16, 484, 685, 54, 349, 11, 2, 2, 45, 58, 2, 13, 197, 12, 16, 43, 23, 2, 5, 62, 30, 145, 402, 11, 2, 51, 575, 32, 61, 369, 71, 66, 770, 12, 2, 75, 100, 2, 8, 4, 105, 37, 69, 147, 712, 75, 2, 44, 257, 390, 5, 69, 263, 514, 105, 50, 286, 2, 23, 4, 123, 13, 161, 40, 5, 421, 4, 116, 16, 897, 13, 2, 40, 319, 2, 112, 2, 11, 2, 121, 25, 70, 2, 4, 719, 2, 13, 18, 31, 62, 40, 8, 2, 4, 2, 7, 14, 123, 5, 942, 25, 8, 721, 12, 145, 5, 202, 12, 160, 580, 202, 12, 6, 52, 58, 2, 92, 401, 728, 12, 39, 14, 251, 8, 15, 251, 5, 2, 12, 38, 84, 80, 124, 12, 9, 23])
#  list([1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8, 106, 14, 123, 4, 2, 270, 2, 5, 2, 2, 732, 2, 101, 405, 39, 14, 2, 4, 2, 9, 115, 50, 305, 12, 47, 4, 168, 5, 235, 7, 38, 111, 699, 102, 7, 4, 2, 2, 9, 24, 6, 78, 2, 17, 2, 2, 21, 27, 2, 2, 5, 2, 2, 92, 2, 4, 2, 7, 4, 204, 42, 97, 90, 35, 221, 109, 29, 127, 27, 118, 8, 97, 12, 157, 21, 2, 2, 9, 6, 66, 78, 2, 4, 631, 2, 5, 2, 272, 191, 2, 6, 2, 8, 2, 2, 2, 544, 5, 383, 2, 848, 2, 2, 497, 2, 8, 2, 2, 2, 21, 60, 27, 239, 9, 43, 2, 209, 405, 10, 10, 12, 764, 40, 4, 248, 20, 12, 16, 5, 174, 2, 72, 7, 51, 6, 2, 22, 4, 204, 131, 9])]

# %%
plt.plot(train_data[0])
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %% [markdown]
# # 과대적합 예제
# 과대적합을 막는 가장 간단한 방법은 모델의 규모를 축소하는 것입니다. 즉, 모델에 있는 학습 가능한 파라미터의 수를 줄입니다(모델 파라미터는 층(layer)의 개수와 층의 유닛(unit) 개수에 의해 결정됩니다). 딥러닝에서는 모델의 학습 가능한 파라미터의 수를 종종 모델의 "용량"이라고 말합니다. 직관적으로 생각해 보면 많은 파라미터를 가진 모델이 더 많은 "기억 용량"을 가집니다. 이런 모델은 훈련 샘플과 타깃 사이를 일반화 능력이 없는 딕셔너리와 같은 매핑으로 완벽하게 학습할 수 있습니다. 하지만 이전에 본 적 없는 데이터에서 예측을 할 땐 쓸모가 없을 것입니다.
#
# 항상 기억해야 할 점은 딥러닝 모델이 훈련 세트에는 학습이 잘 되는 경향이 있지만 진짜 해결할 문제는 학습이 아니라 일반화라는 것입니다.
#
# 반면에 네트워크의 기억 용량이 부족하다면 이런 매핑을 쉽게 학습할 수 없을 것입니다. 손실을 최소화하기 위해서는 예측 성능이 더 많은 압축된 표현을 학습해야 합니다. 또한 너무 작은 모델을 만들면 훈련 데이터를 학습하기 어렵울 것입니다. "너무 많은 용량"과 "충분하지 않은 용량" 사이의 균형을 잡아야 합니다.
#
# 안타깝지만 어떤 모델의 (층의 개수나 뉴런 개수에 해당하는) 적절한 크기나 구조를 결정하는 마법같은 공식은 없습니다. 여러 가지 다른 구조를 사용해 실험을 해봐야만 합니다.
#
# 알맞은 모델의 크기를 찾으려면 비교적 적은 수의 층과 파라미터로 시작해서 검증 손실이 감소할 때까지 새로운 층을 추가하거나 층의 크기를 늘리는 것이 좋습니다. 영화 리뷰 분류 네트워크를 사용해 이를 실험해 보죠.

# %%
baseline_model = keras.Sequential([
    # `.summary` 메서드 때문에 `input_shape`가 필요합니다
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                16016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 0s - loss: 0.6000 - accuracy: 0.7006 - binary_crossentropy: 0.6000 - val_loss: 0.4680 - val_accuracy: 0.8065 - val_binary_crossentropy: 0.4680
# Epoch 2/20
# 49/49 - 0s - loss: 0.3871 - accuracy: 0.8406 - binary_crossentropy: 0.3871 - val_loss: 0.3525 - val_accuracy: 0.8516 - val_binary_crossentropy: 0.3525
# Epoch 3/20
# 49/49 - 0s - loss: 0.3277 - accuracy: 0.8641 - binary_crossentropy: 0.3277 - val_loss: 0.3337 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.3337
# Epoch 4/20
# 49/49 - 0s - loss: 0.3104 - accuracy: 0.8724 - binary_crossentropy: 0.3104 - val_loss: 0.3318 - val_accuracy: 0.8587 - val_binary_crossentropy: 0.3318
# Epoch 5/20
# 49/49 - 0s - loss: 0.3036 - accuracy: 0.8751 - binary_crossentropy: 0.3036 - val_loss: 0.3286 - val_accuracy: 0.8602 - val_binary_crossentropy: 0.3286
# Epoch 6/20
# 49/49 - 0s - loss: 0.2983 - accuracy: 0.8770 - binary_crossentropy: 0.2983 - val_loss: 0.3298 - val_accuracy: 0.8600 - val_binary_crossentropy: 0.3298
# Epoch 7/20
# 49/49 - 0s - loss: 0.2927 - accuracy: 0.8804 - binary_crossentropy: 0.2927 - val_loss: 0.3307 - val_accuracy: 0.8597 - val_binary_crossentropy: 0.3307
# Epoch 8/20
# 49/49 - 0s - loss: 0.2896 - accuracy: 0.8804 - binary_crossentropy: 0.2896 - val_loss: 0.3330 - val_accuracy: 0.8590 - val_binary_crossentropy: 0.3330
# Epoch 9/20
# 49/49 - 0s - loss: 0.2826 - accuracy: 0.8849 - binary_crossentropy: 0.2826 - val_loss: 0.3327 - val_accuracy: 0.8598 - val_binary_crossentropy: 0.3327
# Epoch 10/20
# 49/49 - 0s - loss: 0.2770 - accuracy: 0.8864 - binary_crossentropy: 0.2770 - val_loss: 0.3335 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.3335
# Epoch 11/20
# 49/49 - 0s - loss: 0.2713 - accuracy: 0.8879 - binary_crossentropy: 0.2713 - val_loss: 0.3362 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3362
# Epoch 12/20
# 49/49 - 0s - loss: 0.2652 - accuracy: 0.8905 - binary_crossentropy: 0.2652 - val_loss: 0.3373 - val_accuracy: 0.8575 - val_binary_crossentropy: 0.3373
# Epoch 13/20
# 49/49 - 0s - loss: 0.2571 - accuracy: 0.8936 - binary_crossentropy: 0.2571 - val_loss: 0.3421 - val_accuracy: 0.8560 - val_binary_crossentropy: 0.3421
# Epoch 14/20
# 49/49 - 0s - loss: 0.2494 - accuracy: 0.8981 - binary_crossentropy: 0.2494 - val_loss: 0.3461 - val_accuracy: 0.8544 - val_binary_crossentropy: 0.3461
# Epoch 15/20
# 49/49 - 0s - loss: 0.2413 - accuracy: 0.9023 - binary_crossentropy: 0.2413 - val_loss: 0.3508 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.3508
# Epoch 16/20
# 49/49 - 0s - loss: 0.2327 - accuracy: 0.9062 - binary_crossentropy: 0.2327 - val_loss: 0.3554 - val_accuracy: 0.8524 - val_binary_crossentropy: 0.3554
# Epoch 17/20
# 49/49 - 0s - loss: 0.2260 - accuracy: 0.9103 - binary_crossentropy: 0.2260 - val_loss: 0.3630 - val_accuracy: 0.8503 - val_binary_crossentropy: 0.3630
# Epoch 18/20
# 49/49 - 0s - loss: 0.2183 - accuracy: 0.9128 - binary_crossentropy: 0.2183 - val_loss: 0.3696 - val_accuracy: 0.8495 - val_binary_crossentropy: 0.3696
# Epoch 19/20
# 49/49 - 0s - loss: 0.2104 - accuracy: 0.9182 - binary_crossentropy: 0.2104 - val_loss: 0.3743 - val_accuracy: 0.8486 - val_binary_crossentropy: 0.3743
# Epoch 20/20
# 49/49 - 0s - loss: 0.2049 - accuracy: 0.9195 - binary_crossentropy: 0.2049 - val_loss: 0.3825 - val_accuracy: 0.8480 - val_binary_crossentropy: 0.3825

# %% [markdown]
# # 작은 모델 만들기
# 앞서 만든 기준 모델과 비교하기 위해 적은 수의 은닉 유닛을 가진 모델을 만들어 보죠:

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 4004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 4,029
# Trainable params: 4,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 0s - loss: 0.6321 - accuracy: 0.6815 - binary_crossentropy: 0.6321 - val_loss: 0.5558 - val_accuracy: 0.7845 - val_binary_crossentropy: 0.5558
# Epoch 2/20
# 49/49 - 0s - loss: 0.4870 - accuracy: 0.8154 - binary_crossentropy: 0.4870 - val_loss: 0.4364 - val_accuracy: 0.8295 - val_binary_crossentropy: 0.4364
# Epoch 3/20
# 49/49 - 0s - loss: 0.3940 - accuracy: 0.8446 - binary_crossentropy: 0.3940 - val_loss: 0.3746 - val_accuracy: 0.8475 - val_binary_crossentropy: 0.3746
# Epoch 4/20
# 49/49 - 0s - loss: 0.3483 - accuracy: 0.8593 - binary_crossentropy: 0.3483 - val_loss: 0.3486 - val_accuracy: 0.8551 - val_binary_crossentropy: 0.3486
# Epoch 5/20
# 49/49 - 0s - loss: 0.3267 - accuracy: 0.8651 - binary_crossentropy: 0.3267 - val_loss: 0.3376 - val_accuracy: 0.8583 - val_binary_crossentropy: 0.3376
# Epoch 6/20
# 49/49 - 0s - loss: 0.3148 - accuracy: 0.8703 - binary_crossentropy: 0.3148 - val_loss: 0.3318 - val_accuracy: 0.8601 - val_binary_crossentropy: 0.3318
# Epoch 7/20
# 49/49 - 0s - loss: 0.3079 - accuracy: 0.8737 - binary_crossentropy: 0.3079 - val_loss: 0.3298 - val_accuracy: 0.8616 - val_binary_crossentropy: 0.3298
# Epoch 8/20
# 49/49 - 0s - loss: 0.3039 - accuracy: 0.8762 - binary_crossentropy: 0.3039 - val_loss: 0.3296 - val_accuracy: 0.8605 - val_binary_crossentropy: 0.3296
# Epoch 9/20
# 49/49 - 0s - loss: 0.3010 - accuracy: 0.8762 - binary_crossentropy: 0.3010 - val_loss: 0.3324 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3324
# Epoch 10/20
# 49/49 - 0s - loss: 0.2991 - accuracy: 0.8767 - binary_crossentropy: 0.2991 - val_loss: 0.3293 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3293
# Epoch 11/20
# 49/49 - 0s - loss: 0.2982 - accuracy: 0.8780 - binary_crossentropy: 0.2982 - val_loss: 0.3299 - val_accuracy: 0.8601 - val_binary_crossentropy: 0.3299
# Epoch 12/20
# 49/49 - 0s - loss: 0.2975 - accuracy: 0.8789 - binary_crossentropy: 0.2975 - val_loss: 0.3301 - val_accuracy: 0.8598 - val_binary_crossentropy: 0.3301
# Epoch 13/20
# 49/49 - 0s - loss: 0.2964 - accuracy: 0.8782 - binary_crossentropy: 0.2964 - val_loss: 0.3302 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3302
# Epoch 14/20
# 49/49 - 0s - loss: 0.2958 - accuracy: 0.8779 - binary_crossentropy: 0.2958 - val_loss: 0.3326 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.3326
# Epoch 15/20
# 49/49 - 0s - loss: 0.2958 - accuracy: 0.8776 - binary_crossentropy: 0.2958 - val_loss: 0.3315 - val_accuracy: 0.8593 - val_binary_crossentropy: 0.3315
# Epoch 16/20
# 49/49 - 0s - loss: 0.2954 - accuracy: 0.8790 - binary_crossentropy: 0.2954 - val_loss: 0.3317 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.3317
# Epoch 17/20
# 49/49 - 0s - loss: 0.2951 - accuracy: 0.8804 - binary_crossentropy: 0.2951 - val_loss: 0.3316 - val_accuracy: 0.8594 - val_binary_crossentropy: 0.3316
# Epoch 18/20
# 49/49 - 0s - loss: 0.2946 - accuracy: 0.8792 - binary_crossentropy: 0.2946 - val_loss: 0.3322 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3322
# Epoch 19/20
# 49/49 - 0s - loss: 0.2943 - accuracy: 0.8790 - binary_crossentropy: 0.2943 - val_loss: 0.3320 - val_accuracy: 0.8590 - val_binary_crossentropy: 0.3320
# Epoch 20/20
# 49/49 - 0s - loss: 0.2941 - accuracy: 0.8792 - binary_crossentropy: 0.2941 - val_loss: 0.3325 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3325

# %% [markdown]
# # 큰 모델 만들기
# 아주 큰 모델을 만들어 얼마나 빠르게 과대적합이 시작되는지 알아 볼 수 있습니다. 이 문제에 필요한 것보다 훨씬 더 큰 용량을 가진 네트워크를 추가해서 비교해 보죠:

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 775,681
# Trainable params: 775,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 2s - loss: 0.4084 - accuracy: 0.8190 - binary_crossentropy: 0.4084 - val_loss: 0.3289 - val_accuracy: 0.8593 - val_binary_crossentropy: 0.3289
# Epoch 2/20
# 49/49 - 2s - loss: 0.2896 - accuracy: 0.8819 - binary_crossentropy: 0.2896 - val_loss: 0.3253 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3253
# Epoch 3/20
# 49/49 - 2s - loss: 0.2270 - accuracy: 0.9102 - binary_crossentropy: 0.2270 - val_loss: 0.3426 - val_accuracy: 0.8538 - val_binary_crossentropy: 0.3426
# Epoch 4/20
# 49/49 - 2s - loss: 0.1114 - accuracy: 0.9638 - binary_crossentropy: 0.1114 - val_loss: 0.4279 - val_accuracy: 0.8397 - val_binary_crossentropy: 0.4279
# Epoch 5/20
# 49/49 - 2s - loss: 0.0317 - accuracy: 0.9939 - binary_crossentropy: 0.0317 - val_loss: 0.4974 - val_accuracy: 0.8479 - val_binary_crossentropy: 0.4974
# Epoch 6/20
# 49/49 - 2s - loss: 0.0060 - accuracy: 0.9998 - binary_crossentropy: 0.0060 - val_loss: 0.5846 - val_accuracy: 0.8525 - val_binary_crossentropy: 0.5846
# Epoch 7/20
# 49/49 - 2s - loss: 0.0018 - accuracy: 1.0000 - binary_crossentropy: 0.0018 - val_loss: 0.6300 - val_accuracy: 0.8519 - val_binary_crossentropy: 0.6300
# Epoch 8/20
# 49/49 - 2s - loss: 8.9819e-04 - accuracy: 1.0000 - binary_crossentropy: 8.9819e-04 - val_loss: 0.6623 - val_accuracy: 0.8525 - val_binary_crossentropy: 0.6623
# Epoch 9/20
# 49/49 - 2s - loss: 5.9509e-04 - accuracy: 1.0000 - binary_crossentropy: 5.9509e-04 - val_loss: 0.6903 - val_accuracy: 0.8532 - val_binary_crossentropy: 0.6903
# Epoch 10/20
# 49/49 - 2s - loss: 4.2698e-04 - accuracy: 1.0000 - binary_crossentropy: 4.2698e-04 - val_loss: 0.7151 - val_accuracy: 0.8533 - val_binary_crossentropy: 0.7151
# Epoch 11/20
# 49/49 - 2s - loss: 3.1732e-04 - accuracy: 1.0000 - binary_crossentropy: 3.1732e-04 - val_loss: 0.7370 - val_accuracy: 0.8530 - val_binary_crossentropy: 0.7370
# Epoch 12/20
# 49/49 - 2s - loss: 2.4169e-04 - accuracy: 1.0000 - binary_crossentropy: 2.4169e-04 - val_loss: 0.7587 - val_accuracy: 0.8533 - val_binary_crossentropy: 0.7587
# Epoch 13/20
# 49/49 - 2s - loss: 1.8636e-04 - accuracy: 1.0000 - binary_crossentropy: 1.8636e-04 - val_loss: 0.7785 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.7785
# Epoch 14/20
# 49/49 - 2s - loss: 1.4703e-04 - accuracy: 1.0000 - binary_crossentropy: 1.4703e-04 - val_loss: 0.7977 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.7977
# Epoch 15/20
# 49/49 - 2s - loss: 1.1777e-04 - accuracy: 1.0000 - binary_crossentropy: 1.1777e-04 - val_loss: 0.8141 - val_accuracy: 0.8532 - val_binary_crossentropy: 0.8141
# Epoch 16/20
# 49/49 - 2s - loss: 9.6245e-05 - accuracy: 1.0000 - binary_crossentropy: 9.6245e-05 - val_loss: 0.8299 - val_accuracy: 0.8532 - val_binary_crossentropy: 0.8299
# Epoch 17/20
# 49/49 - 2s - loss: 7.9082e-05 - accuracy: 1.0000 - binary_crossentropy: 7.9082e-05 - val_loss: 0.8464 - val_accuracy: 0.8531 - val_binary_crossentropy: 0.8464
# Epoch 18/20
# 49/49 - 2s - loss: 6.5849e-05 - accuracy: 1.0000 - binary_crossentropy: 6.5849e-05 - val_loss: 0.8608 - val_accuracy: 0.8531 - val_binary_crossentropy: 0.8608
# Epoch 19/20
# 49/49 - 2s - loss: 5.5514e-05 - accuracy: 1.0000 - binary_crossentropy: 5.5514e-05 - val_loss: 0.8748 - val_accuracy: 0.8528 - val_binary_crossentropy: 0.8748
# Epoch 20/20
# 49/49 - 2s - loss: 4.7252e-05 - accuracy: 1.0000 - binary_crossentropy: 4.7252e-05 - val_loss: 0.8872 - val_accuracy: 0.8531 - val_binary_crossentropy: 0.8872

# %% [markdown]
# # 훈련 손실과 검증 손실 그래프 그리기
# 실선은 훈련 손실이고 점선은 검증 손실입니다(낮은 검증 손실이 더 좋은 모델입니다). 여기서는 작은 네트워크가 기준 모델보다 더 늦게 과대적합이 시작되었습니다(즉 에포크 4가 아니라 6에서 시작됩니다). 또한 과대적합이 시작되고 훨씬 천천히 성능이 감소합니다.

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# 큰 네트워크는 거의 바로 첫 번째 에포크 이후에 과대적합이 시작되고 훨씬 더 심각하게 과대적합됩니다. 네트워크의 용량이 많을수록 훈련 세트를 더 빠르게 모델링할 수 있습니다(훈련 손실이 낮아집니다). 하지만 더 쉽게 과대적합됩니다(훈련 손실과 검증 손실 사이에 큰 차이가 발생합니다).
#
# # 과대적합을 방지하기 위한 전략
# ## 가중치를 규제하기
# 아마도 오캄의 면도날(Occam's Razor) 이론을 들어 보았을 것입니다. 어떤 것을 설명하는 두 가지 방법이 있다면 더 정확한 설명은 최소한의 가정이 필요한 가장 "간단한" 설명일 것입니다. 이는 신경망으로 학습되는 모델에도 적용됩니다. 훈련 데이터와 네트워크 구조가 주어졌을 때 이 데이터를 설명할 수 있는 가중치의 조합(즉, 가능한 모델)은 많습니다. 간단한 모델은 복잡한 것보다 과대적합되는 경향이 작을 것입니다.
#
# 여기서 "간단한 모델"은 모델 파라미터의 분포를 봤을 때 엔트로피(entropy)가 작은 모델입니다(또는 앞 절에서 보았듯이 적은 파라미터를 가진 모델입니다). 따라서 과대적합을 완화시키는 일반적인 방법은 가중치가 작은 값을 가지도록 네트워크의 복잡도에 제약을 가하는 것입니다. 이는 가중치 값의 분포를 좀 더 균일하게 만들어 줍니다. 이를 "가중치 규제"(weight regularization)라고 부릅니다. 네트워크의 손실 함수에 큰 가중치에 해당하는 비용을 추가합니다. 이 비용은 두 가지 형태가 있습니다:
#
# L1 규제는 가중치의 절댓값에 비례하는 비용이 추가됩니다(즉, 가중치의 "L1 노름(norm)"을 추가합니다).
#
# L2 규제는 가중치의 제곱에 비례하는 비용이 추가됩니다(즉, 가중치의 "L2 노름"의 제곱을 추가합니다). 신경망에서는 L2 규제를 가중치 감쇠(weight decay)라고도 부릅니다. 이름이 다르지만 혼돈하지 마세요. 가중치 감쇠는 수학적으로 L2 규제와 동일합니다.
#
# L1 규제는 일부 가중치 파라미터를 0으로 만듭니다. L2 규제는 가중치 파라미터를 제한하지만 완전히 0으로 만들지는 않습니다. 이것이 L2 규제를 더 많이 사용하는 이유 중 하나입니다.
#
# tf.keras에서는 가중치 규제 객체를 층의 키워드 매개변수에 전달하여 가중치에 규제를 추가합니다. L2 가중치 규제를 추가해 보죠.

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6049 - accuracy: 0.7177 - binary_crossentropy: 0.5604 - val_loss: 0.4573 - val_accuracy: 0.8237 - val_binary_crossentropy: 0.4137
# Epoch 2/20
# 49/49 - 0s - loss: 0.4057 - accuracy: 0.8470 - binary_crossentropy: 0.3624 - val_loss: 0.3942 - val_accuracy: 0.8489 - val_binary_crossentropy: 0.3514
# Epoch 3/20
# 49/49 - 0s - loss: 0.3624 - accuracy: 0.8678 - binary_crossentropy: 0.3203 - val_loss: 0.3718 - val_accuracy: 0.8609 - val_binary_crossentropy: 0.3306
# Epoch 4/20
# 49/49 - 0s - loss: 0.3491 - accuracy: 0.8730 - binary_crossentropy: 0.3086 - val_loss: 0.3703 - val_accuracy: 0.8603 - val_binary_crossentropy: 0.3307
# Epoch 5/20
# 49/49 - 0s - loss: 0.3427 - accuracy: 0.8753 - binary_crossentropy: 0.3038 - val_loss: 0.3681 - val_accuracy: 0.8591 - val_binary_crossentropy: 0.3300
# Epoch 6/20
# 49/49 - 0s - loss: 0.3369 - accuracy: 0.8782 - binary_crossentropy: 0.2995 - val_loss: 0.3639 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3271
# Epoch 7/20
# 49/49 - 0s - loss: 0.3327 - accuracy: 0.8786 - binary_crossentropy: 0.2964 - val_loss: 0.3622 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3264
# Epoch 8/20
# 49/49 - 0s - loss: 0.3289 - accuracy: 0.8791 - binary_crossentropy: 0.2934 - val_loss: 0.3607 - val_accuracy: 0.8601 - val_binary_crossentropy: 0.3256
# Epoch 9/20
# 49/49 - 0s - loss: 0.3244 - accuracy: 0.8793 - binary_crossentropy: 0.2897 - val_loss: 0.3614 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3269
# Epoch 10/20
# 49/49 - 0s - loss: 0.3201 - accuracy: 0.8818 - binary_crossentropy: 0.2856 - val_loss: 0.3593 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3249
# Epoch 11/20
# 49/49 - 0s - loss: 0.3168 - accuracy: 0.8812 - binary_crossentropy: 0.2824 - val_loss: 0.3617 - val_accuracy: 0.8594 - val_binary_crossentropy: 0.3273
# Epoch 12/20
# 49/49 - 0s - loss: 0.3088 - accuracy: 0.8869 - binary_crossentropy: 0.2743 - val_loss: 0.3610 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3265
# Epoch 13/20
# 49/49 - 0s - loss: 0.3040 - accuracy: 0.8889 - binary_crossentropy: 0.2693 - val_loss: 0.3670 - val_accuracy: 0.8555 - val_binary_crossentropy: 0.3320
# Epoch 14/20
# 49/49 - 0s - loss: 0.3001 - accuracy: 0.8896 - binary_crossentropy: 0.2648 - val_loss: 0.3640 - val_accuracy: 0.8580 - val_binary_crossentropy: 0.3284
# Epoch 15/20
# 49/49 - 0s - loss: 0.2947 - accuracy: 0.8922 - binary_crossentropy: 0.2589 - val_loss: 0.3653 - val_accuracy: 0.8591 - val_binary_crossentropy: 0.3291
# Epoch 16/20
# 49/49 - 0s - loss: 0.2877 - accuracy: 0.8970 - binary_crossentropy: 0.2511 - val_loss: 0.3675 - val_accuracy: 0.8578 - val_binary_crossentropy: 0.3305
# Epoch 17/20
# 49/49 - 0s - loss: 0.2837 - accuracy: 0.8975 - binary_crossentropy: 0.2462 - val_loss: 0.3697 - val_accuracy: 0.8576 - val_binary_crossentropy: 0.3318
# Epoch 18/20
# 49/49 - 0s - loss: 0.2750 - accuracy: 0.9057 - binary_crossentropy: 0.2365 - val_loss: 0.3785 - val_accuracy: 0.8536 - val_binary_crossentropy: 0.3396
# Epoch 19/20
# 49/49 - 0s - loss: 0.2699 - accuracy: 0.9077 - binary_crossentropy: 0.2303 - val_loss: 0.3794 - val_accuracy: 0.8539 - val_binary_crossentropy: 0.3393
# Epoch 20/20
# 49/49 - 0s - loss: 0.2627 - accuracy: 0.9115 - binary_crossentropy: 0.2220 - val_loss: 0.3848 - val_accuracy: 0.8533 - val_binary_crossentropy: 0.3435

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
# # 드롭아웃 추가하기
# 드롭아웃(dropout)은 신경망에서 가장 효과적이고 널리 사용하는 규제 기법 중 하나입니다. 토론토(Toronto) 대학의 힌튼(Hinton)과 그의 제자들이 개발했습니다. 드롭아웃을 층에 적용하면 훈련하는 동안 층의 출력 특성을 랜덤하게 끕니다(즉, 0으로 만듭니다). 훈련하는 동안 어떤 입력 샘플에 대해 [0.2, 0.5, 1.3, 0.8, 1.1] 벡터를 출력하는 층이 있다고 가정해 보죠. 드롭아웃을 적용하면 이 벡터에서 몇 개의 원소가 랜덤하게 0이 됩니다. 예를 들면, [0, 0.5, 1.3, 0, 1.1]가 됩니다. "드롭아웃 비율"은 0이 되는 특성의 비율입니다. 보통 0.2에서 0.5 사이를 사용합니다. 테스트 단계에서는 어떤 유닛도 드롭아웃하지 않습니다. 훈련 단계보다 더 많은 유닛이 활성화되기 때문에 균형을 맞추기 위해 층의 출력 값을 드롭아웃 비율만큼 줄입니다.
#
# tf.keras에서는 Dropout 층을 이용해 네트워크에 드롭아웃을 추가할 수 있습니다. 이 층은 바로 이전 층의 출력에 드롭아웃을 적용합니다.
#
# IMDB 네트워크에 두 개의 Dropout 층을 추가하여 과대적합이 얼마나 감소하는지 알아 보겠습니다:

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6815 - accuracy: 0.5510 - binary_crossentropy: 0.6815 - val_loss: 0.6388 - val_accuracy: 0.7319 - val_binary_crossentropy: 0.6388
# Epoch 2/20
# 49/49 - 0s - loss: 0.6068 - accuracy: 0.6629 - binary_crossentropy: 0.6068 - val_loss: 0.5099 - val_accuracy: 0.8134 - val_binary_crossentropy: 0.5099
# Epoch 3/20
# 49/49 - 0s - loss: 0.5131 - accuracy: 0.7452 - binary_crossentropy: 0.5131 - val_loss: 0.4030 - val_accuracy: 0.8447 - val_binary_crossentropy: 0.4030
# Epoch 4/20
# 49/49 - 0s - loss: 0.4496 - accuracy: 0.7961 - binary_crossentropy: 0.4496 - val_loss: 0.3558 - val_accuracy: 0.8532 - val_binary_crossentropy: 0.3558
# Epoch 5/20
# 49/49 - 0s - loss: 0.4138 - accuracy: 0.8207 - binary_crossentropy: 0.4138 - val_loss: 0.3412 - val_accuracy: 0.8558 - val_binary_crossentropy: 0.3412
# Epoch 6/20
# 49/49 - 0s - loss: 0.3902 - accuracy: 0.8350 - binary_crossentropy: 0.3902 - val_loss: 0.3302 - val_accuracy: 0.8582 - val_binary_crossentropy: 0.3302
# Epoch 7/20
# 49/49 - 0s - loss: 0.3769 - accuracy: 0.8449 - binary_crossentropy: 0.3769 - val_loss: 0.3265 - val_accuracy: 0.8584 - val_binary_crossentropy: 0.3265
# Epoch 8/20
# 49/49 - 0s - loss: 0.3674 - accuracy: 0.8488 - binary_crossentropy: 0.3674 - val_loss: 0.3240 - val_accuracy: 0.8594 - val_binary_crossentropy: 0.3240
# Epoch 9/20
# 49/49 - 0s - loss: 0.3544 - accuracy: 0.8551 - binary_crossentropy: 0.3544 - val_loss: 0.3222 - val_accuracy: 0.8604 - val_binary_crossentropy: 0.3222
# Epoch 10/20
# 49/49 - 0s - loss: 0.3492 - accuracy: 0.8599 - binary_crossentropy: 0.3492 - val_loss: 0.3222 - val_accuracy: 0.8602 - val_binary_crossentropy: 0.3222
# Epoch 11/20
# 49/49 - 0s - loss: 0.3406 - accuracy: 0.8658 - binary_crossentropy: 0.3406 - val_loss: 0.3227 - val_accuracy: 0.8595 - val_binary_crossentropy: 0.3227
# Epoch 12/20
# 49/49 - 0s - loss: 0.3346 - accuracy: 0.8688 - binary_crossentropy: 0.3346 - val_loss: 0.3232 - val_accuracy: 0.8601 - val_binary_crossentropy: 0.3232
# Epoch 13/20
# 49/49 - 0s - loss: 0.3260 - accuracy: 0.8701 - binary_crossentropy: 0.3260 - val_loss: 0.3243 - val_accuracy: 0.8593 - val_binary_crossentropy: 0.3243
# Epoch 14/20
# 49/49 - 0s - loss: 0.3222 - accuracy: 0.8722 - binary_crossentropy: 0.3222 - val_loss: 0.3278 - val_accuracy: 0.8569 - val_binary_crossentropy: 0.3278
# Epoch 15/20
# 49/49 - 0s - loss: 0.3196 - accuracy: 0.8738 - binary_crossentropy: 0.3196 - val_loss: 0.3298 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3298
# Epoch 16/20
# 49/49 - 0s - loss: 0.3139 - accuracy: 0.8748 - binary_crossentropy: 0.3139 - val_loss: 0.3307 - val_accuracy: 0.8571 - val_binary_crossentropy: 0.3307
# Epoch 17/20
# 49/49 - 0s - loss: 0.3057 - accuracy: 0.8798 - binary_crossentropy: 0.3057 - val_loss: 0.3313 - val_accuracy: 0.8578 - val_binary_crossentropy: 0.3313
# Epoch 18/20
# 49/49 - 0s - loss: 0.3022 - accuracy: 0.8798 - binary_crossentropy: 0.3022 - val_loss: 0.3353 - val_accuracy: 0.8570 - val_binary_crossentropy: 0.3353
# Epoch 19/20
# 49/49 - 0s - loss: 0.3028 - accuracy: 0.8828 - binary_crossentropy: 0.3028 - val_loss: 0.3358 - val_accuracy: 0.8550 - val_binary_crossentropy: 0.3358
# Epoch 20/20
# 49/49 - 0s - loss: 0.2980 - accuracy: 0.8854 - binary_crossentropy: 0.2980 - val_loss: 0.3391 - val_accuracy: 0.8556 - val_binary_crossentropy: 0.3391

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %% [markdown]
# 드롭아웃을 추가하니 기준 모델보다 확실히 향상되었습니다.
#
# 정리하면 신경망에서 과대적합을 방지하기 위해 가장 널리 사용하는 방법은 다음과 같습니다:
#
# - 더 많은 훈련 데이터를 모읍니다.
# - 네트워크의 용량을 줄입니다.
# - 가중치 규제를 추가합니다.
# - 드롭아웃을 추가합니다.
#
# 이 문서에서 다루지 않은 중요한 방법 두 가지는 데이터 증식(data-augmentation)과 배치 정규화(batch normalization)입니다.
